# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo-Perico/DataScience/blob/main/group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'Classe': ['Júnior', 'Júnior', 'Pleno', 'Pleno', 'Sênior', 'Sênior'],
    'Nome': ['Jorge', 'Carlos', 'Roberta', 'Patrícia', 'Bruno', 'Vera'],
    'Venda': [200, 120, 340, 124, 243, 350]
}

# %%
df = pd.DataFrame(data)

# %%
x= df.groupby("Classe")

# %%
df.groupby("Classe").min()
# Out:
#             Nome  Venda
# Classe
# Júnior    Carlos    120
# Pleno   Patrícia    124
# Sênior     Bruno    243

# %%
df.groupby(["Classe", "Nome"]).sum()
# Out:
#                  Venda
# Classe Nome
# Júnior Carlos      120
#        Jorge       200
# Pleno  Patrícia    124
#        Roberta     340
# Sênior Bruno       243
#        Vera        350

# %%
df2 = df.copy()
df3 = pd.concat([df, df2])

# %%
df3
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %%
df3.groupby(['Classe', 'Nome']).sum()
# Out:
#                  Venda
# Classe Nome
# Júnior Carlos      240
#        Jorge       400
# Pleno  Patrícia    248
#        Roberta     680
# Sênior Bruno       486
#        Vera        700
