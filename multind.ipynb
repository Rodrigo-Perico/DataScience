# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo-Perico/DataScience/blob/main/multind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import numpy as np

# %%
fora = ["G1","G1","G1","G2","G2","G2"]

# %%
dentro = [1,2,3,1,2,3]

# %%
indexx = list(zip(fora, dentro))

# %%
indexx
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
multind = pd.MultiIndex.from_tuples(indexx)

# %%
df = pd.DataFrame(np.random.randn(6,2), index = multind, columns= ["A","B"])
df
# Out:
#              A         B
# G1 1  1.737882  0.604721
#    2  0.522945  1.225908
#    3  0.808018 -1.271839
# G2 1 -0.613676  0.305193
#    2 -0.087944 -1.747291
#    3 -1.752717 -0.360341

# %%
df.loc["G1"]
# Out:
#                 A         B
# Pessoas
# 1        1.737882  0.604721
# 2        0.522945  1.225908
# 3        0.808018 -1.271839

# %%
df.loc["G1"].loc[1]
# Out:
# A    1.737882
# B    0.604721
# Name: 1, dtype: float64

# %%
df.index.names = ['Grupo', 'Pessoas']

# %%
df.xs(3, level = 'Pessoas')
# Out:
#               A         B
# Grupo
# G1     0.808018 -1.271839
# G2    -1.752717 -0.360341
